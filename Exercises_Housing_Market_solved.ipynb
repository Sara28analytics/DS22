# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Step 2. Create 3 differents Series, each of length 100, as follows:
# The first a random number from 1 to 4
# The second a random number from 1 to 3
# The third a random number from 10,000 to 30,000

# %%
series1 = pd.Series(np.random.randint(1,4,100))
series1
series2 = pd.Series(np.random.randint(1,3,100))
series2
series3 = pd.Series(np.random.randint(10000,30000,100))
series3
# Out:
# 0     26354
# 1     26688
# 2     25374
# 3     22624
# 4     24120
#       ...
# 95    14750
# 96    24006
# 97    13032
# 98    29096
# 99    16124
# Length: 100, dtype: int64

# %% [markdown]
# Step 3. Let's create a DataFrame by joinning the Series by column

# %%
housedata=pd.concat([series1,series2,series3],axis=1)
housedata
# Out:
#     0  1      2
# 0   1  1  26354
# 1   3  1  26688
# 2   3  1  25374
# 3   3  2  22624
# 4   2  1  24120
# .. .. ..    ...
# 95  3  1  14750
# 96  3  1  24006
# 97  1  2  13032
# 98  1  1  29096
# 99  2  2  16124
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
housedata.rename(columns={0:'bedrs',1:'bathrs',2:'price_sqr_meter'})
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            26354
# 1       3       1            26688
# 2       3       1            25374
# 3       3       2            22624
# 4       2       1            24120
# ..    ...     ...              ...
# 95      3       1            14750
# 96      3       1            24006
# 97      1       2            13032
# 98      1       1            29096
# 99      2       2            16124
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn =pd.concat([series1,series2,series3],axis=0)
bigcolumn=bigcolumn.to_frame()
bigcolumn
# Out:
#         0
# 0       1
# 1       3
# 2       3
# 3       3
# 4       2
# ..    ...
# 95  14750
# 96  24006
# 97  13032
# 98  29096
# 99  16124
#
# [300 rows x 1 columns]

# %% [markdown]
# Step 6. Oops, it seems it is going only until index 99. Is it true?

# %% [markdown]
# No

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index(inplace=True,drop=True)
bigcolumn
# Out:
#          0
# 0        1
# 1        3
# 2        3
# 3        3
# 4        2
# ..     ...
# 295  14750
# 296  24006
# 297  13032
# 298  29096
# 299  16124
#
# [300 rows x 1 columns]
